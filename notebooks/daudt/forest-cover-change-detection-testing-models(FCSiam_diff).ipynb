# %%
import warnings

warnings.filterwarnings(action='ignore')

import time
import torch
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from tqdm.notebook import tqdm
from torch.optim import AdamW
from torch.optim.lr_scheduler import ReduceLROnPlateau, OneCycleLR
from torch import nn
from torch.utils.data import random_split, DataLoader
from torchvision.io import read_image
from torchvision.transforms.functional import resize
from forest_cover_change_detection.dataloaders.change import ChangeDetectionDataset
from forest_cover_change_detection.models.fc_siam import FCSiam
from forest_cover_change_detection.trainer.train import Compile
from forest_cover_change_detection.metrics.accuracy import *

# %% [markdown]
# ### Loading Data

# %%
data_set = ChangeDetectionDataset('../../data/annotated',
                                  '../../data/patch_train.csv',
                                  concat=False,
                                  patched=True
                                  )

# %%
len(data_set)
# Out:
# 1336

# %%
imgs, label = data_set[np.random.randint(0, data_set.__len__())]
fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(14, 8), dpi=100)
axes = axes.ravel()

axes[0].imshow(imgs[0].permute(1, 2, 0).numpy())
axes[1].imshow(imgs[1].permute(1, 2, 0).numpy())
axes[2].imshow(label.numpy(), cmap='gray')

axes[0].axis(False)
axes[1].axis(False)
axes[2].axis(False)

print(imgs[0].shape, imgs[1].shape, label.shape)
# Out:
# torch.Size([3, 256, 256]) torch.Size([3, 256, 256]) torch.Size([256, 256])

# %%
train_size = int(len(data_set) * 0.8)
test_size = len(data_set) - train_size

train_dataset, test_dataset = random_split(data_set, (train_size, test_size))

train_dataloader = DataLoader(train_dataset, batch_size=32, shuffle=True)
test_dataloader = DataLoader(test_dataset, batch_size=32, shuffle=True)

len(train_dataloader), len(test_dataloader)
# Out:
# (34, 9)

# %% [markdown]
# ### Modeling

# %%
model = FCSiam(3, classes=2, diff=True)

# %%
optimizer = AdamW(model.parameters(), lr=0.001)
scheduler = ReduceLROnPlateau(optimizer, factor=0.1, cooldown=10)
# scheduler = OneCycleLR(optimizer, max_lr=0.01, steps_per_epoch=len(train_dataloader), epochs=50)

compiled = Compile(model,
                   optimizer,
                   lr_scheduler=scheduler
                   )

# %%
compiled.summary([(3, 256, 256), (3, 256, 256)])
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1         [-1, 16, 256, 256]             448
#        BatchNorm2d-2         [-1, 16, 256, 256]              32
#               ReLU-3         [-1, 16, 256, 256]               0
#            Dropout-4         [-1, 16, 256, 256]               0
#             Conv2d-5         [-1, 16, 256, 256]           2,320
#        BatchNorm2d-6         [-1, 16, 256, 256]              32
#               ReLU-7         [-1, 16, 256, 256]               0
#            Dropout-8         [-1, 16, 256, 256]               0
#          MaxPool2d-9         [-1, 16, 128, 128]               0
#            Conv2d-10         [-1, 32, 128, 128]           4,640
#       BatchNorm2d-11         [-1, 32, 128, 128]              64
#              ReLU-12         [-1, 32, 128, 128]               0
#           Dropout-13         [-1, 32, 128, 128]               0
#            Conv2d-14         [-1, 32, 128, 128]           9,248
#       BatchNorm2d-15         [-1, 32, 128, 128]              64
#              ReLU-16         [-1, 32, 128, 128]               0
#           Dropout-17         [-1, 32, 128, 128]               0
#         MaxPool2d-18           [-1, 32, 64, 64]               0
#            Conv2d-19           [-1, 64, 64, 64]          18,496
#       BatchNorm2d-20           [-1, 64, 64, 64]             128
#              ReLU-21           [-1, 64, 64, 64]               0
#           Dropout-22           [-1, 64, 64, 64]               0
#            Conv2d-23           [-1, 64, 64, 64]          36,928
#       BatchNorm2d-24           [-1, 64, 64, 64]             128
#              ReLU-25           [-1, 64, 64, 64]               0
#           Dropout-26           [-1, 64, 64, 64]               0
#            Conv2d-27           [-1, 64, 64, 64]          36,928
#       BatchNorm2d-28           [-1, 64, 64, 64]             128
#              ReLU-29           [-1, 64, 64, 64]               0
#           Dropout-30           [-1, 64, 64, 64]               0
#         MaxPool2d-31           [-1, 64, 32, 32]               0
#            Conv2d-32          [-1, 128, 32, 32]          73,856
#       BatchNorm2d-33          [-1, 128, 32, 32]             256
#              ReLU-34          [-1, 128, 32, 32]               0
#           Dropout-35          [-1, 128, 32, 32]               0
#            Conv2d-36          [-1, 128, 32, 32]         147,584
#       BatchNorm2d-37          [-1, 128, 32, 32]             256
#              ReLU-38          [-1, 128, 32, 32]               0
#           Dropout-39          [-1, 128, 32, 32]               0
#            Conv2d-40          [-1, 128, 32, 32]         147,584
#       BatchNorm2d-41          [-1, 128, 32, 32]             256
#              ReLU-42          [-1, 128, 32, 32]               0
#           Dropout-43          [-1, 128, 32, 32]               0
#         MaxPool2d-44          [-1, 128, 16, 16]               0
#            Conv2d-45         [-1, 16, 256, 256]             448
#       BatchNorm2d-46         [-1, 16, 256, 256]              32
#              ReLU-47         [-1, 16, 256, 256]               0
#           Dropout-48         [-1, 16, 256, 256]               0
#            Conv2d-49         [-1, 16, 256, 256]           2,320
#       BatchNorm2d-50         [-1, 16, 256, 256]              32
#              ReLU-51         [-1, 16, 256, 256]               0
#           Dropout-52         [-1, 16, 256, 256]               0
#         MaxPool2d-53         [-1, 16, 128, 128]               0
#            Conv2d-54         [-1, 32, 128, 128]           4,640
#       BatchNorm2d-55         [-1, 32, 128, 128]              64
#              ReLU-56         [-1, 32, 128, 128]               0
#           Dropout-57         [-1, 32, 128, 128]               0
#            Conv2d-58         [-1, 32, 128, 128]           9,248
#       BatchNorm2d-59         [-1, 32, 128, 128]              64
#              ReLU-60         [-1, 32, 128, 128]               0
#           Dropout-61         [-1, 32, 128, 128]               0
#         MaxPool2d-62           [-1, 32, 64, 64]               0
#            Conv2d-63           [-1, 64, 64, 64]          18,496
#       BatchNorm2d-64           [-1, 64, 64, 64]             128
#              ReLU-65           [-1, 64, 64, 64]               0
#           Dropout-66           [-1, 64, 64, 64]               0
#            Conv2d-67           [-1, 64, 64, 64]          36,928
#       BatchNorm2d-68           [-1, 64, 64, 64]             128
#              ReLU-69           [-1, 64, 64, 64]               0
#           Dropout-70           [-1, 64, 64, 64]               0
#            Conv2d-71           [-1, 64, 64, 64]          36,928
#       BatchNorm2d-72           [-1, 64, 64, 64]             128
#              ReLU-73           [-1, 64, 64, 64]               0
#           Dropout-74           [-1, 64, 64, 64]               0
#         MaxPool2d-75           [-1, 64, 32, 32]               0
#            Conv2d-76          [-1, 128, 32, 32]          73,856
#       BatchNorm2d-77          [-1, 128, 32, 32]             256
#              ReLU-78          [-1, 128, 32, 32]               0
#           Dropout-79          [-1, 128, 32, 32]               0
#            Conv2d-80          [-1, 128, 32, 32]         147,584
#       BatchNorm2d-81          [-1, 128, 32, 32]             256
#              ReLU-82          [-1, 128, 32, 32]               0
#           Dropout-83          [-1, 128, 32, 32]               0
#            Conv2d-84          [-1, 128, 32, 32]         147,584
#       BatchNorm2d-85          [-1, 128, 32, 32]             256
#              ReLU-86          [-1, 128, 32, 32]               0
#           Dropout-87          [-1, 128, 32, 32]               0
#   ConvTranspose2d-88          [-1, 128, 34, 34]         147,584
#   ConvTranspose2d-89          [-1, 128, 32, 32]         295,040
#   ConvTranspose2d-90          [-1, 128, 32, 32]         295,040
#       BatchNorm2d-91          [-1, 128, 32, 32]             256
#              ReLU-92          [-1, 128, 32, 32]               0
#           Dropout-93          [-1, 128, 32, 32]               0
#   ConvTranspose2d-94          [-1, 128, 32, 32]         147,584
#       BatchNorm2d-95          [-1, 128, 32, 32]             256
#              ReLU-96          [-1, 128, 32, 32]               0
#           Dropout-97          [-1, 128, 32, 32]               0
#   ConvTranspose2d-98           [-1, 64, 32, 32]          73,792
#       BatchNorm2d-99           [-1, 64, 32, 32]             128
#             ReLU-100           [-1, 64, 32, 32]               0
#          Dropout-101           [-1, 64, 32, 32]               0
#  ConvTranspose2d-102           [-1, 64, 66, 66]          36,928
#  ConvTranspose2d-103           [-1, 64, 64, 64]          73,792
#  ConvTranspose2d-104           [-1, 64, 64, 64]          73,792
#      BatchNorm2d-105           [-1, 64, 64, 64]             128
#             ReLU-106           [-1, 64, 64, 64]               0
#          Dropout-107           [-1, 64, 64, 64]               0
#  ConvTranspose2d-108           [-1, 64, 64, 64]          36,928
#      BatchNorm2d-109           [-1, 64, 64, 64]             128
#             ReLU-110           [-1, 64, 64, 64]               0
#          Dropout-111           [-1, 64, 64, 64]               0
#  ConvTranspose2d-112           [-1, 32, 64, 64]          18,464
#      BatchNorm2d-113           [-1, 32, 64, 64]              64
#             ReLU-114           [-1, 32, 64, 64]               0
#          Dropout-115           [-1, 32, 64, 64]               0
#  ConvTranspose2d-116         [-1, 32, 130, 130]           9,248
#  ConvTranspose2d-117         [-1, 32, 128, 128]          18,464
#  ConvTranspose2d-118         [-1, 32, 128, 128]          18,464
#      BatchNorm2d-119         [-1, 32, 128, 128]              64
#             ReLU-120         [-1, 32, 128, 128]               0
#          Dropout-121         [-1, 32, 128, 128]               0
#  ConvTranspose2d-122         [-1, 16, 128, 128]           4,624
#      BatchNorm2d-123         [-1, 16, 128, 128]              32
#             ReLU-124         [-1, 16, 128, 128]               0
#          Dropout-125         [-1, 16, 128, 128]               0
#  ConvTranspose2d-126         [-1, 16, 258, 258]           2,320
#  ConvTranspose2d-127         [-1, 16, 256, 256]           4,624
#  ConvTranspose2d-128         [-1, 16, 256, 256]           4,624
#      BatchNorm2d-129         [-1, 16, 256, 256]              32
#             ReLU-130         [-1, 16, 256, 256]               0
#          Dropout-131         [-1, 16, 256, 256]               0
#  ConvTranspose2d-132          [-1, 2, 256, 256]             290
#       LogSoftmax-133          [-1, 2, 256, 256]               0
# ================================================================
# Total params: 2,221,442
# Trainable params: 2,221,442
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 389.76
# Params size (MB): 8.47
# Estimated Total Size (MB): 398.23
# ----------------------------------------------------------------

# %%
compiled.visual_graph([(32, 3, 256, 256), (32, 3, 256, 256)])
# Out:
# (dot.exe:6808): Pango-WARNING **: couldn't load font "Linux libertine Not-Rotated 10", falling back to "Sans Not-Rotated 10", expect ugly output.

# %%
w = torch.load('../../data/annotated/class_weight.pt')
w
# Out:
# tensor([0.0962, 1.9038], device='cuda:0')

# %%
# torch.FloatTensor([0.0962, 0.2]).cuda()

results = compiled.train(train_dataloader,
                         nn.NLLLoss(w),
                         100,
                         test_dataloader,
                         multi_in=True
                         )
# Out:
# Epoch:   0%|          | 0/100 [00:00<?, ?it/s]
# Epoch: 
# val loss: 0.4277101854483287
# Epoch: 75/100
# train loss: 0.27791009098291397
# val loss: 0.43535318308406407
# Epoch: 76/100
# train loss: 0.2777217652867822
# val loss: 0.4349415947993596
# Epoch: 77/100
# train loss: 0.2795201005304561
# val loss: 0.44554586542977226
# Epoch: 78/100
# train loss: 0.2806845281053992
# val loss: 0.4382249547375573
# Epoch: 79/100
# train loss: 0.2859833976801704
# val loss: 0.42271583941247726
# Epoch: 80/100
# train loss: 0.28431325099047494
# val loss: 0.41653483774926925
# Epoch: 81/100
# train loss: 0.281625904581126
# val loss: 0.3895967702070872
# Epoch: 82/100
# train loss: 0.28235045031589623
# val loss: 0.4291577935218811
# Epoch: 83/100
# train loss: 0.28435002617976246
# val loss: 0.44437339570787215
# Epoch: 84/100
# train loss: 0.2793571239008623
# val loss: 0.42221780949168736
# Epoch: 85/100
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[12], line 3
#       1 # torch.FloatTensor([0.0962, 0.2]).cuda()
# ----> 3 results = compiled.train(train_dataloader,
#       4                          nn.NLLLoss(w),
#       5                          100,
#       6                          test_dataloader,
#       7                          multi_in=True
#       8                          )
#
# File T:\Forest cover shrinking\forest_cover_change_detection\trainer\train.py:41, in Compile.train(self, train_dataloader, loss, epochs, val_dataloader, multi_in)
#      39 self.validation = True if val_dataloader is not None else False
#      40 self.loss = loss
# ---> 41 self.results = train_loop(model=self.model,
#      42                           loss_func=self.loss,
#      43                           train_loader=train_dataloader,
#      44                           test_loader=None,
#      45                           val_loader=val_dataloader,
#      46                           score_funcs=self.metrics,
#      47                           epochs=epochs,
#      48                           device=self.device,
#      49                           optimizer=self.optimizer,
#      50                           lr_schedule=self.lr_scheduler,
#      51                           multi_in=multi_in
#      52                           )
#      53 return self.results
#
# File T:\Forest cover shrinking\forest_cover_change_detection\trainer\utils.py:205, in train_loop(model, loss_func, train_loader, test_loader, val_loader, score_funcs, epochs, device, optimizer, lr_schedule, checkpoint_file, keep_best, multi_in)
#     202 # epoch number
#     203 print(f"Epoch: {epoch}/{epochs}")
# --> 205 run_epoch(model, optimizer, train_loader, loss_func, device, results, score_funcs,
#     206           prefix="train", desc="Training", multi_in=multi_in)
#     208 results["total time"].append(total_train_time)
#     209 results["epoch"].append(epoch)
#
# File T:\Forest cover shrinking\forest_cover_change_detection\trainer\utils.py:94, in run_epoch(model, optimizer, data_loader, loss_func, device, results, score_funcs, multi_in, prefix, desc, epoch)
#      90     y_hat, loss = do_training_with_multiple_in(model=model, optimizer=optimizer, inputs=inputs,
#      91                                                labels=labels, loss_func=loss_func)
#      93 # Now we are just grabbing some information we would like to have
# ---> 94 running_loss.append(loss.item())
#      96 if len(score_funcs) > 0 and isinstance(labels, torch.Tensor):
#      97     # moving labels & predictions back to CPU for computing / storing predictions
#      98     labels = labels.detach().cpu().numpy()
#
# KeyboardInterrupt:

# %%
# restore best checkpoint
state = torch.load("./last-checkpoint.pth")
model.load_state_dict(state['model_state_dict'])
# Out:
# <All keys matched successfully>

# %%
plt.figure(figsize=(12, 6), dpi=200)
sns.lineplot(x=results['epoch'], y=np.log(results['train loss']), label='train')
sns.lineplot(x=results['epoch'], y=np.log(results['val loss']), label='validation')
plt.ylabel('loss (log)')
plt.show()

# %%
df = pd.read_csv('../../data/annotated/train.csv')

# %%
acc_test = []
change_acc = []
no_change_acc = []
p = []
r = []
d = []
k = []
metrics = pd.DataFrame()

for i, row in tqdm(df.iterrows()):
    img, gt = (read_image(f'../../data/annotated/{row.dir}/{row.img_1}'),
               read_image(f'../../data/annotated/{row.dir}/{row.img_2}')), read_image(
        f'../../data/annotated/{row.label}')

    img1 = resize(img[0], size=[256, 256]) / 255.0
    img2 = resize(img[1], size=[256, 256]) / 255.0
    gt = resize(gt, size=[256, 256]).squeeze(0) / 255.0

    with torch.no_grad():
        model.eval()
        logits = model(img1.unsqueeze(0).to('cuda'),
                       img2.unsqueeze(0).to('cuda'))[0].cpu()
        pred = torch.argmax(torch.sigmoid(logits), dim=0)

    class_acc = class_accuracy(gt, logits)

    acc_test.append(pixel_accuracy(gt, pred).numpy().tolist())
    p.append(precision(gt, pred).numpy().tolist())
    r.append(recall(gt, pred).numpy().tolist())
    d.append(dice(gt, pred).numpy().tolist())
    k.append(kappa(gt, pred).numpy().tolist())
    no_change_acc.append(class_acc[0])
    change_acc.append(class_acc[1])

metrics['overall accuracy'] = acc_test
metrics['change accuracy'] = change_acc
metrics['no change accuracy'] = no_change_acc
metrics['precision'] = p
metrics['recall'] = r
metrics['dice'] = d
metrics['kappa'] = k
# Out:
# 0it [00:00, ?it/s]

# %%
metrics.mean()
# Out:
# overall accuracy      0.840952
# change accuracy       0.457772
# no change accuracy    0.856400
# precision             0.216471
# recall                0.435936
# dice                  0.248690
# kappa                 0.187665
# dtype: float64

# %%
sample = pd.read_csv('../../data/annotated/train.csv').sample(1)
img, gt = (read_image(f'../../data/annotated/{sample.dir.values[0]}/{sample.img_1.values[0]}'),
           read_image(f'../../data/annotated/{sample.dir.values[0]}/{sample.img_2.values[0]}')), read_image(
    f'../../data/annotated/{sample.label.values[0]}')

img1 = resize(img[0], size=[256, 256]) / 255.0
img2 = resize(img[1], size=[256, 256]) / 255.0
gt = resize(gt, size=[256, 256]).squeeze(0) / 255.0

with torch.no_grad():
    model.eval()
    logits = model(img1.unsqueeze(0).to('cuda'),
                   img2.unsqueeze(0).to('cuda'))[0].cpu()
    pred = torch.argmax(torch.sigmoid(logits), dim=0)

plt.figure(figsize=(16, 10))
plt.subplot(1, 4, 1)
plt.imshow(img1.permute(1, 2, 0), cmap='gray')
plt.subplot(1, 4, 3)
plt.imshow(gt, cmap='gray')
plt.subplot(1, 4, 2)
plt.imshow(img2.permute(1, 2, 0), cmap='gray')
plt.subplot(1, 4, 4)
plt.imshow(pred, cmap='gray')

# %%
pixel_accuracy(gt, pred), precision(gt, pred), recall(gt, pred), dice(gt, pred), kappa(gt, pred), class_accuracy(gt, pred)
# Out:
# (tensor(0.8425),
#  tensor(0.4556),
#  tensor(0.7039),
#  tensor(0.5532),
#  tensor(0.4628),
#  [0.0, 0.0])
