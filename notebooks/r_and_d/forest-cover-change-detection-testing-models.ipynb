# %%
import os
import warnings

import pandas as pd

warnings.filterwarnings(action='ignore')

from notebooks.r_and_d.model_results_vis import vis_models_prediction
from notebooks.r_and_d.metrics import (training_summary, metric_summary,
                                       training_curves, model_heatmap)

# %% [markdown]
# ### Loading metrical data

# %%
single_in = metric_summary('./v2')
multi_in = metric_summary('./v2/multi_in')
comp_df = pd.concat((single_in, multi_in))

# %%
comp_df
# Out:
#                           overall accuracy  change accuracy  \
# v2_fcef_focat                     0.784987         0.742545
# v2_fcef_res                       0.877012         0.680189
# v2_fcef_resnst_focat              0.828630         0.648912
# v2_fcef_res_aat                   0.877729         0.616712
# v2_fcef_res_focat                 0.845873         0.703332
# v2_fcef_res_nst                   0.895032         0.607707
# v2_fcef_res_nst_aat               0.881666         0.621665
# v2_fcef_res_nxt                   0.901680         0.602272
# v2_fcef_res_se                    0.859976         0.701501
# v2_fcfe                           0.894066         0.625165
# v2_fcfe_aat                       0.891718         0.621149
# multi_in_fcef_aat                 0.883668         0.666841
# multi_in_fcef_res                 0.883423         0.671735
# multi_in_fcef_res_aat             0.876419         0.693857
# multi_in_fcef_res_nst             0.859137         0.694412
# multi_in_fcef_res_se              0.887866         0.624698
# multi_in_fcef_res_se_aat          0.887866         0.624698
# multi_in_fcfe                     0.874122         0.652497
#
#                           no change accuracy  precision    recall      dice  \
# v2_fcef_focat                       0.772962   0.171356  0.718624  0.269269
# v2_fcef_res                         0.870706   0.252563  0.632240  0.329413
# v2_fcef_resnst_focat                0.817479   0.218945  0.603671  0.289301
# v2_fcef_res_aat                     0.872177   0.249766  0.576973  0.324235
# v2_fcef_res_focat                   0.839790   0.224770  0.674894  0.305519
# v2_fcef_res_nst                     0.893051   0.254488  0.575072  0.331732
# v2_fcef_res_nst_aat                 0.877798   0.242683  0.593025  0.332778
# v2_fcef_res_nxt                     0.900752   0.263516  0.568518  0.335931
# v2_fcef_res_se                      0.851739   0.231215  0.669244  0.311939
# v2_fcfe                             0.893219   0.236939  0.581917  0.323615
# v2_fcfe_aat                         0.888279   0.247641  0.585714  0.319978
# multi_in_fcef_aat                   0.880669   0.274346  0.633902  0.334698
# multi_in_fcef_res                   0.878165   0.258392  0.645635  0.336456
# multi_in_fcef_res_aat               0.871388   0.246213  0.662611  0.333693
# multi_in_fcef_res_nst               0.850610   0.217161  0.665812  0.304703
# multi_in_fcef_res_se                0.884030   0.268978  0.576178  0.343111
# multi_in_fcef_res_se_aat            0.884030   0.268978  0.576178  0.343111
# multi_in_fcfe                       0.869761   0.252238  0.622400  0.336785
#
#                              kappa        f1
# v2_fcef_focat             0.204156  0.276727
# v2_fcef_res               0.283861  0.360940
# v2_fcef_resnst_focat      0.224525  0.321343
# v2_fcef_res_aat           0.277348  0.348619
# v2_fcef_res_focat         0.258617  0.337228
# v2_fcef_res_nst           0.278788  0.352835
# v2_fcef_res_nst_aat       0.277330  0.344420
# v2_fcef_res_nxt           0.285488  0.360114
# v2_fcef_res_se            0.261824  0.343689
# v2_fcfe                   0.269655  0.336760
# v2_fcfe_aat               0.275308  0.348103
# multi_in_fcef_aat         0.292409  0.382954
# multi_in_fcef_res         0.292536  0.369075
# multi_in_fcef_res_aat     0.288098  0.359021
# multi_in_fcef_res_nst     0.252479  0.327503
# multi_in_fcef_res_se      0.288199  0.366747
# multi_in_fcef_res_se_aat  0.288199  0.366747
# multi_in_fcfe             0.282505  0.358989

# %%
t1, v1 = training_summary('./v2/')
t2, v2 = training_summary('./v2/multi_in')

t = pd.concat((t1, t2), axis=1)
v = pd.concat((v1, v2), axis=1)

# %%
comp_df
# Out:
#                    overall accuracy  change accuracy  no change accuracy  \
# fcfe                       0.784987         0.742545            0.772962
# fcfe res                   0.877012         0.680189            0.870706
# fcfe res se                0.828630         0.648912            0.817479
# fcfe res nxt               0.877729         0.616712            0.872177
# fcfe res nst               0.845873         0.703332            0.839790
# fcfe aat                   0.895032         0.607707            0.893051
# fcef res aat               0.881666         0.621665            0.877798
# fcef resnst aat            0.901680         0.602272            0.900752
# fcef focat                 0.859976         0.701501            0.851739
# fcef res focat             0.894066         0.625165            0.893219
# fcef resnst focat          0.891718         0.621149            0.888279
# fcef mi                    0.883668         0.666841            0.880669
# fcef res mi                0.883423         0.671735            0.878165
# fcef res se mi             0.876419         0.693857            0.871388
# fcef resnst mi             0.859137         0.694412            0.850610
# fcef aat mi                0.887866         0.624698            0.884030
# fcef res aat mi            0.887866         0.624698            0.884030
# 6                          0.874122         0.652497            0.869761
#
#                    precision    recall      dice     kappa        f1
# fcfe                0.171356  0.718624  0.269269  0.204156  0.276727
# fcfe res            0.252563  0.632240  0.329413  0.283861  0.360940
# fcfe res se         0.218945  0.603671  0.289301  0.224525  0.321343
# fcfe res nxt        0.249766  0.576973  0.324235  0.277348  0.348619
# fcfe res nst        0.224770  0.674894  0.305519  0.258617  0.337228
# fcfe aat            0.254488  0.575072  0.331732  0.278788  0.352835
# fcef res aat        0.242683  0.593025  0.332778  0.277330  0.344420
# fcef resnst aat     0.263516  0.568518  0.335931  0.285488  0.360114
# fcef focat          0.231215  0.669244  0.311939  0.261824  0.343689
# fcef res focat      0.236939  0.581917  0.323615  0.269655  0.336760
# fcef resnst focat   0.247641  0.585714  0.319978  0.275308  0.348103
# fcef mi             0.274346  0.633902  0.334698  0.292409  0.382954
# fcef res mi         0.258392  0.645635  0.336456  0.292536  0.369075
# fcef res se mi      0.246213  0.662611  0.333693  0.288098  0.359021
# fcef resnst mi      0.217161  0.665812  0.304703  0.252479  0.327503
# fcef aat mi         0.268978  0.576178  0.343111  0.288199  0.366747
# fcef res aat mi     0.268978  0.576178  0.343111  0.288199  0.366747
# 6                   0.252238  0.622400  0.336785  0.282505  0.358989

# %% [markdown]
# ### Visualization

# %%
labels = ['fcef focat', 'fcef res', 'fcef resnst focat', 'fcef res aat',
          'fcef res focat', 'fcef res nst', 'fcef res nst aat', 'fcef res nxt',
          'fcef res se', 'fcfe', 'fcfe aat', 'fcef res mi', 'fcef res nst mi',
          'fcef res se mi', 'fcef mi', 'fcef aat mi']

# %%
training_curves(t, v, labels)

# %%
model_heatmap(comp_df, labels)

# %%
dict([(64,56), (128,28), (256,14) ,(512,7)])
# Out:
# {64: 56, 128: 28, 256: 14, 512: 7}
